# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
plt.plot('default')

# %%
# !unzip drive-download-20260730T164837Z-1-001.zip
# Out:
# Archive:  drive-download-20260730T164837Z-1-001.zip
# replace sharma-kohli.csv? [y]es, [n]o, [A]ll, [N]one, [r]ename: ^C

# %%
# !unzip drive-download-20260730T164941Z-1-001.zip

# %%
df = pd.read_csv('sharma-kohli.csv')

# %%
df
# Out:
#    index  RG Sharma  V Kohli
# 0   2008        404      165
# 1   2009        362      246
# 2   2010        404      307
# 3   2011        372      557
# 4   2012        433      364
# 5   2013        538      639
# 6   2014        390      359
# 7   2015        482      505
# 8   2016        489      973
# 9   2017        333      308

# %%
plt.plot(df['RG Sharma'],color='blue',label='sharma')
plt.plot(df['V Kohli'],color='red',label='kohli')
plt.lim(0,1000)
plt.legend()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[26], line 3
#       1 plt.plot(df['RG Sharma'],color='blue',label='sharma')
#       2 plt.plot(df['V Kohli'],color='red',label='kohli')
# ----> 3 plt.lim(0,1000)
#       4 plt.legend()
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'lim'
