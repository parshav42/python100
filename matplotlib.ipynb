# %%
import matplotlib.pyplot as plt
import pandas as p
import numpy as np

# %%
# !unzip drive-download-20260730T164837Z-1-001.zip

# %%
# !unzip drive-download-20260730T164941Z-1-001.zip
# Out:
# Archive:  drive-download-20260730T164941Z-1-001.zip
# replace batsman_season_record.csv? [y]es, [n]o, [A]ll, [N]one, [r]ename: ^C
